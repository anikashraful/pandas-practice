# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'Name' : ['Anik', 'Manik', 'Alice'],
    'Age' : [22, 33, 44],
    'Job' : ['Progmr', 'Clerk', 'Designer']
})
df = df.set_index('Name')

# %%
df.loc['Anik']
# Out:
# Age        22
# Job    Progmr
# Name: Anik, dtype: object

# %%
df = df.reset_index()
df
# Out:
#     Name  Age       Job
# 0   Anik   22    Progmr
# 1  Manik   33     Clerk
# 2  Alice   44  Designer

# %%
df.to_csv('01_pandas.csv', index=None)

# %%
pd.read_csv('01_pandas.csv', index_col=0)
# Out:
#        Age       Job
# Name
# Anik    22    Progmr
# Manik   33     Clerk
# Alice   44  Designer

# %%
df.loc[1]
# Out:
# Name    Manik
# Age        33
# Job     Clerk
# Name: 1, dtype: object
